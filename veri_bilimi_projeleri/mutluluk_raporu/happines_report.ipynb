# %% [markdown]
# # World Happines Report EDA

# %% [markdown]
# ##### This data is great for exploratory data analysis and data visualization. And for this purpose I want to realize my first implementation with plotly library which is really cool.
#
# ##### Bu veriseti keşifsel veri analizi ve veri görselleştirmesi için çok iyi veriseti. Ben de bu amaçla bayağı havalı grafikler çizmeyi mümkün kılan plotly kütüphanesiyle ilk uygulamamı gerçekleştirmek istiyorum.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %% [markdown]
# # Loading Data

# %%
data = pd.read_csv("../input/world-happiness-report-2021/world-happiness-report.csv")
data.fillna(0, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1949 non-null   float64
#  4   Social support                    1949 non-null   float64
#  5   Healthy life expectancy at birth  1949 non-null   float64
#  6   Freedom to make life choices      1949 non-null   float64
#  7   Generosity                        1949 non-null   float64
#  8   Perceptions of corruption         1949 non-null   float64
#  9   Positive affect                   1949 non-null   float64
#  10  Negative affect                   1949 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 167.6+ KB

# %%
data.rename(columns={"Country name" : "country",
                    "Life Ladder" : "ladder_score",
                    "Log GDP per capita" : "gdp_per_capita",
                    "Social support" : "social_support",
                    "Healthy life expectancy at birth" : "life_expectancy",
                    "Freedom to make life choices" : "freedom",
                    "Generosity" : "generosity",
                    "Perceptions of corruption" : "corruption",
                    "Positive affect" : "positive_affect",
                    "Negative affect" : "negative_affect"},
           inplace=True)

# %%
data.describe()
# Out:
#               year  ladder_score  gdp_per_capita  social_support  \
# count  1949.000000   1949.000000     1949.000000     1949.000000
# mean   2013.216008      5.466705        9.195408        0.807132
# std       4.166828      1.115711        1.702742        0.135355
# min    2005.000000      2.375000        0.000000        0.000000
# 25%    2010.000000      4.640000        8.397000        0.747000
# 50%    2013.000000      5.386000        9.443000        0.834000
# 75%    2017.000000      6.283000       10.335000        0.905000
# max    2020.000000      8.019000       11.648000        0.987000
#
#        life_expectancy      freedom   generosity   corruption  \
# count      1949.000000  1949.000000  1949.000000  1949.000000
# mean         61.571398     0.730366     0.000099     0.704958
# std          12.843519     0.169611     0.158466     0.250322
# min           0.000000     0.000000    -0.335000     0.000000
# 25%          57.500000     0.642000    -0.106000     0.654000
# 50%          65.000000     0.759000    -0.016000     0.793000
# 75%          68.400000     0.854000     0.085000     0.868000
# max          77.100000     0.985000     0.698000     0.983000
#
#        positive_affect  negative_affect
# count      1949.000000      1949.000000
# mean          0.701989         0.266340
# std           0.130268         0.088213
# min           0.000000         0.000000
# 25%           0.622000         0.206000
# 50%           0.718000         0.257000
# 75%           0.798000         0.319000
# max           0.944000         0.705000

# %%
data.head(20)
# Out:
#         country  year  ladder_score  gdp_per_capita  social_support  \
# 0   Afghanistan  2008         3.724           7.370           0.451
# 1   Afghanistan  2009         4.402           7.540           0.552
# 2   Afghanistan  2010         4.758           7.647           0.539
# 3   Afghanistan  2011         3.832           7.620           0.521
# 4   Afghanistan  2012         3.783           7.705           0.521
# 5   Afghanistan  2013         3.572           7.725           0.484
# 6   Afghanistan  2014         3.131           7.718           0.526
# 7   Afghanistan  2015         3.983           7.702           0.529
# 8   Afghanistan  2016         4.220           7.697           0.559
# 9   Afghanistan  2017         2.662           7.697           0.491
# 10  Afghanistan  2018         2.694           7.692           0.508
# 11  Afghanistan  2019         2.375           7.697           0.420
# 12      Albania  2007         4.634           9.142           0.821
# 13      Albania  2009         5.485           9.262           0.833
# 14      Albania  2010         5.269           9.303           0.733
# 15      Albania  2011         5.867           9.331           0.759
# 16      Albania  2012         5.510           9.347           0.785
# 17      Albania  2013         4.551           9.359           0.759
# 18      Albania  2014         4.814           9.378           0.626
# 19      Albania  2015         4.607           9.403           0.639
#
#     life_expectancy  freedom  generosity  corruption  positive_affect  \
# 0             50.80    0.718       0.168       0.882            0.518
# 1             51.20    0.679       0.190       0.850            0.584
# 2             51.60    0.600       0.121       0.707            0.618
# 3             51.92    0.496       0.162       0.731            0.611
# 4             52.24    0.531       0.236       0.776            0.710
# 5             52.56    0.578       0.061       0.823            0.621
# 6             52.88    0.509       0.104       0.871            0.532
# 7             53.20    0.389       0.080       0.881            0.554
# 8             53.00    0.523       0.042       0.793            0.565
# 9             52.80    0.427      -0.121       0.954            0.496
# 10            52.60    0.374      -0.094       0.928            0.424
# 11            52.40    0.394      -0.108       0.924            0.351
# 12            65.80    0.529      -0.009       0.875            0.553
# 13            66.20    0.525      -0.158       0.864            0.640
# 14            66.40    0.569      -0.172       0.726            0.648
# 15            66.68    0.487      -0.205       0.877            0.628
# 16            66.96    0.602      -0.169       0.848            0.607
# 17            67.24    0.632      -0.127       0.863            0.634
# 18            67.52    0.735      -0.025       0.883            0.685
# 19            67.80    0.704      -0.081       0.885            0.688
#
#     negative_affect
# 0             0.258
# 1             0.237
# 2             0.275
# 3             0.267
# 4             0.268
# 5             0.273
# 6             0.375
# 7             0.339
# 8             0.348
# 9             0.371
# 10            0.405
# 11            0.502
# 12            0.246
# 13            0.279
# 14            0.300
# 15            0.257
# 16            0.271
# 17            0.338
# 18            0.335
# 19            0.350

# %%
data_ = pd.read_csv("../input/world-happiness-report-2021/world-happiness-report-2021.csv")
data_.head(3)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839

# %% [markdown]
# #### I'm using the code cell below to insert region feature from second dataframe (named data_) to first dataframe (named as data.) The loop checks entries in country columns and if they are same countries, the entry corresponding to region at that moment is assigned first dataframe's region column's proper index that is corresponding country's matched.
#
# #### TR: 2.dataframedeki region özelliğini ilk (data) dataframe'ine eklemek için aşağıdaki kod parçasını kullanıyorum. country kolonlarındaki girdiler sırasıyla kontrol edilerek eşit olduğu durumda 2.dataframeden regiona karşılık gelen girdiyi ilk dataframede eşit olduğu durumun indeksinde region kolonuna ekler.

# %%
data_.rename(columns={"Regional indicator" : "region", "Country name" : "country"},inplace=True)

data["region"] = np.nan

for i,country in enumerate(data_.country):
    if data["country"].eq(country).any(0):
        ind = data.index[data.eq(country).any(1)]
        data["region"][ind] = data_.region[i]
        
data.head(10)
# Out:
#        country  year  ladder_score  gdp_per_capita  social_support  \
# 0  Afghanistan  2008         3.724           7.370           0.451
# 1  Afghanistan  2009         4.402           7.540           0.552
# 2  Afghanistan  2010         4.758           7.647           0.539
# 3  Afghanistan  2011         3.832           7.620           0.521
# 4  Afghanistan  2012         3.783           7.705           0.521
# 5  Afghanistan  2013         3.572           7.725           0.484
# 6  Afghanistan  2014         3.131           7.718           0.526
# 7  Afghanistan  2015         3.983           7.702           0.529
# 8  Afghanistan  2016         4.220           7.697           0.559
# 9  Afghanistan  2017         2.662           7.697           0.491
#
#    life_expectancy  freedom  generosity  corruption  positive_affect  \
# 0            50.80    0.718       0.168       0.882            0.518
# 1            51.20    0.679       0.190       0.850            0.584
# 2            51.60    0.600       0.121       0.707            0.618
# 3            51.92    0.496       0.162       0.731            0.611
# 4            52.24    0.531       0.236       0.776            0.710
# 5            52.56    0.578       0.061       0.823            0.621
# 6            52.88    0.509       0.104       0.871            0.532
# 7            53.20    0.389       0.080       0.881            0.554
# 8            53.00    0.523       0.042       0.793            0.565
# 9            52.80    0.427      -0.121       0.954            0.496
#
#    negative_affect      region
# 0            0.258  South Asia
# 1            0.237  South Asia
# 2            0.275  South Asia
# 3            0.267  South Asia
# 4            0.268  South Asia
# 5            0.273  South Asia
# 6            0.375  South Asia
# 7            0.339  South Asia
# 8            0.348  South Asia
# 9            0.371  South Asia

# %% [markdown]
# # Filling NaN entries

# %% [markdown]
# #### Checking if there is null entries after merging.
#
# #### Birleştirdikten sonra null girdi oldu mu diye kontrol ediyorum.

# %%
data.isna().sum()
# Out:
# country             0
# year                0
# ladder_score        0
# gdp_per_capita      0
# social_support      0
# life_expectancy     0
# freedom             0
# generosity          0
# corruption          0
# positive_affect     0
# negative_affect     0
# region             63
# dtype: int64

# %% [markdown]
# ####  There is NaN values in region column and I will fill them with proper region by searching their locations
#
# #### TR: region kolonunda NaN girdiler var ve bunları ülkelerin konumlarına göre uygun bölgeyi seçip NaN girdiyi dolduracağım.

# %%
data.region.unique()
# Out:
# array(['South Asia', 'Central and Eastern Europe',
#        'Middle East and North Africa', nan, 'Latin America and Caribbean',
#        'Commonwealth of Independent States', 'North America and ANZ',
#        'Western Europe', 'Sub-Saharan Africa', 'Southeast Asia',
#        'East Asia'], dtype=object)

# %%
null = data[data["region"].isnull()]
null['country'].unique()
# Out:
# array(['Angola', 'Belize', 'Bhutan', 'Central African Republic',
#        'Congo (Kinshasa)', 'Cuba', 'Djibouti', 'Guyana', 'Oman', 'Qatar',
#        'Somalia', 'Somaliland region', 'South Sudan', 'Sudan', 'Suriname',
#        'Syria', 'Trinidad and Tobago'], dtype=object)

# %%
region_list = []

for country in data['country']:
    if country == "Angola":
        region_list.append("Sub-Saharan Africa")
    if country == "Belize":
        region_list.append("Latin America and Caribbean")
    if country == "Bhutan":
        region_list.append("South Asia")
    if country == "Central African Republic":
        region_list.append("Sub-Saharan Africa")
    if country == "Congo (Kinshasa)":
        region_list.append("Sub-Saharan Africa")
    if country == "Cuba":
        region_list.append("Latin America and Caribbean")
    if country == "Djibouti":
        region_list.append("Middle East and North Africa")
    if country == "Guyana":
        region_list.append("Latin America and Caribbean") 
    if country == "Oman":
        region_list.append("Middle East and North Africa")  
    if country == "Qatar":
        region_list.append("Middle East and North Africa") 
    if country == "Somalia":
        region_list.append("Middle East and North Africa") 
    if country == "Somaliland region":
        region_list.append("Sub-Saharan Africa") 
    if country == "South Sudan":
        region_list.append("Sub-Saharan Africa") 
    if country == "Sudan":
        region_list.append("Middle East and North Africa")  
    if country == "Suriname":
        region_list.append("Latin America and Caribbean") 
    if country == "Syria":
        region_list.append("Middle East and North Africa") 
    if country == "Trinidad and Tobago":
        region_list.append("Latin America and Caribbean")     
        
        
for i,j in zip(null.index,range(len(null))):
    data["region"][i] = region_list[j]

# %%
data.isnull().sum()
# Out:
# country            0
# year               0
# ladder_score       0
# gdp_per_capita     0
# social_support     0
# life_expectancy    0
# freedom            0
# generosity         0
# corruption         0
# positive_affect    0
# negative_affect    0
# region             0
# dtype: int64

# %% [markdown]
# #### * *Since there is no missing values, skipping to visualization.*

# %% [markdown]
# # Expolartory Data Analysis

# %% [markdown]
# ### Overview

# %%
fig = px.box(data, x="ladder_score",color_discrete_sequence = ['red'],hover_data=["country"])
fig.update_layout(width=900,height=450,
xaxis_title_text = 'Ladder Score',
template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="5bba7961-3521-43a1-b3c1-ae52b64d60f8" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bba7961-3521-43a1-b3c1-ae52b64d60f8")) {                    Plotly.newPlot(                        "5bba7961-3521-43a1-b3c1-ae52b64d60f8",                        [{"alignmentgroup": "True", "customdata": [["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Angola"], ["Angola"], ["Angola"], ["Angola"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belize"], ["Belize"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Bhutan"], ["Bhutan"], ["Bhutan"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["B ...

# %%
fig = px.box(data, x="freedom",color_discrete_sequence = ['mediumspringgreen'],hover_data=["country"])
fig.update_layout(width=900,height=450,
xaxis_title_text = 'Freedom',
template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="a3065c1c-919f-4e4c-8908-fc04dfb2441c" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3065c1c-919f-4e4c-8908-fc04dfb2441c")) {                    Plotly.newPlot(                        "a3065c1c-919f-4e4c-8908-fc04dfb2441c",                        [{"alignmentgroup": "True", "customdata": [["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Angola"], ["Angola"], ["Angola"], ["Angola"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belize"], ["Belize"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Bhutan"], ["Bhutan"], ["Bhutan"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["B ...

# %%
fig = px.box(data[["corruption","country"]][data["corruption"] > 0], x="corruption",color_discrete_sequence = ['darkviolet'],hover_data=["country"])
fig.update_layout(width=900,height=450,
xaxis_title_text = 'Corruption',
template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="3552ad0a-7837-4b68-af51-8afb5fcaa620" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3552ad0a-7837-4b68-af51-8afb5fcaa620")) {                    Plotly.newPlot(                        "3552ad0a-7837-4b68-af51-8afb5fcaa620",                        [{"alignmentgroup": "True", "customdata": [["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Angola"], ["Angola"], ["Angola"], ["Angola"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belize"], ["Belize"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Bhutan"], ["Bhutan"], ["Bhutan"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgari ...

# %%
fig = px.box(data[["social_support","country"]][data["social_support"] > 0], x="social_support",color_discrete_sequence = ['darkorange'],hover_data=["country"])
fig.update_layout(width=900,height=450,
xaxis_title_text = 'Social Support',
template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="065ad86a-968c-4b4d-ac23-79f1ee6e9866" class="plotly-graph-div" style="height:450px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("065ad86a-968c-4b4d-ac23-79f1ee6e9866")) {                    Plotly.newPlot(                        "065ad86a-968c-4b4d-ac23-79f1ee6e9866",                        [{"alignmentgroup": "True", "customdata": [["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Afghanistan"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Albania"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Algeria"], ["Angola"], ["Angola"], ["Angola"], ["Angola"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Argentina"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Armenia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Australia"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Austria"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Azerbaijan"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bahrain"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Bangladesh"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belarus"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belgium"], ["Belize"], ["Belize"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Benin"], ["Bhutan"], ["Bhutan"], ["Bhutan"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bolivia"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Bosnia and Herzegovina"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Botswana"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Brazil"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], ["Bulgaria"], [ ...

# %%
group = data.groupby('country', as_index=False).mean().sort_values(by='ladder_score',ascending=False)

fig = make_subplots(rows=1, cols=2,
                   subplot_titles=['The Happiest 10 Countries', 'The Unhappiest 10 Countries'])
fig.append_trace(go.Bar(x=group['ladder_score'].head(10),
                       y=group["country"].head(10),
                        orientation='h',
                       marker={'color': '#3366ff','line': dict(color='#3366ff', width=1)},
                       ), 1,1
                )
fig.append_trace(go.Bar(x=group['ladder_score'].tail(10),
                       y=group['country'].tail(10),
                        orientation='h',
                        marker={'color': '#ff9933','line': dict(color='#ff9933', width=1)},
                       ), 1,2
                )
fig.update_layout(
    template='plotly_dark',
    showlegend=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c5f01f31-1934-4569-8011-5bdf3a4cc5b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5f01f31-1934-4569-8011-5bdf3a4cc5b1")) {                    Plotly.newPlot(                        "c5f01f31-1934-4569-8011-5bdf3a4cc5b1",                        [{"marker": {"color": "#3366ff", "line": {"color": "#3366ff", "width": 1}}, "orientation": "h", "type": "bar", "x": [7.6804, 7.597153846153845, 7.5483, 7.512400000000001, 7.466285714285713, 7.4465, 7.376333333333334, 7.369466666666667, 7.3102857142857145, 7.282071428571428], "xaxis": "x", "y": ["Denmark", "Finland", "Switzerland", "Norway", "Netherlands", "Iceland", "Canada", "Sweden", "New Zealand", "Australia"], "yaxis": "y"}, {"marker": {"color": "#ff9933", "line": {"color": "#ff9933", "width": 1}}, "orientation": "h", "type": "bar", "x": [3.9440000000000004, 3.9122500000000002, 3.8826000000000005, 3.6973333333333334, 3.6544166666666666, 3.594666666666667, 3.5550000000000006, 3.5482, 3.5149999999999997, 3.402], "xaxis": "x2", "y": ["Comoros", "Yemen", "Zimbabwe", "Tanzania", "Rwanda", "Afghanistan", "Togo", "Burundi", "Central African Republic", "South Sudan"], "yaxis": "y2"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "The Happiest 10 Countries", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "The Unhappiest 10 Countries", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"] ...

# %%
gdp = data.groupby('country', as_index=False).mean().sort_values(by='gdp_per_capita',ascending=False)
x = gdp[gdp['gdp_per_capita'] > 0].tail(10)

fig = make_subplots(rows=1, cols=2,
                   subplot_titles=['The Highest 10 Countries as GDP per capita', 'The Lowest 10 Countries as GDP per capita'])
fig.append_trace(go.Bar(x=gdp['gdp_per_capita'].head(10),
                       y=gdp["country"].head(10),
                        orientation='h',
                       marker={'color': '#ccccff','line': dict(color='#ccccff', width=1)},
                       ), 1,1
                )
fig.append_trace(go.Bar(x=x['gdp_per_capita'],
                       y=gdp['country'].tail(10),
                        orientation='h',
                        marker={'color': '#99ccff','line': dict(color='#99ccff', width=1)},
                       ), 1,2
                )
fig.update_layout(
    template='plotly_dark',
    showlegend=False,
    title_font_size=16)
fig.show()
# Out:
# <div>                            <div id="a4219320-cfcc-4654-97e5-8d4e1e1eba90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4219320-cfcc-4654-97e5-8d4e1e1eba90")) {                    Plotly.newPlot(                        "a4219320-cfcc-4654-97e5-8d4e1e1eba90",                        [{"marker": {"color": "#ccccff", "line": {"color": "#ccccff", "width": 1}}, "orientation": "h", "type": "bar", "x": [11.607090909090909, 11.5076, 11.328999999999999, 11.0954, 11.064857142857145, 11.059692307692305, 11.0391, 10.974818181818181, 10.956066666666668, 10.886846153846154], "xaxis": "x", "y": ["Luxembourg", "Qatar", "Singapore", "Switzerland", "Ireland", "United Arab Emirates", "Norway", "Kuwait", "United States", "Austria"], "yaxis": "y"}, {"marker": {"color": "#99ccff", "line": {"color": "#99ccff", "width": 1}}, "orientation": "h", "type": "bar", "x": [7.29511111111111, 7.239222222222221, 7.202357142857144, 7.00725, 6.985357142857143, 6.961, 6.884125, 6.883916666666667, 6.752250000000001, 6.7224], "xaxis": "x2", "y": ["Central African Republic", "Congo (Kinshasa)", "Malawi", "Yemen", "Burundi", "Somaliland region", "Cuba", "North Cyprus", "Somalia", "South Sudan"], "yaxis": "y2"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "The Highest 10 Countries as GDP per capita", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "The Lowest 10 Countries as GDP per capita", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, " ...

# %%
free = data.groupby("country",as_index=False).mean().groupby(["country","freedom"], as_index=False).mean().sort_values(by='freedom', ascending=False)

fig = make_subplots(rows=1, cols=2,
                   subplot_titles=['Top 10 Countries as freedom', 'The Lowest 10 Countries as freedom'])
fig.append_trace(go.Bar(x=free['freedom'].head(10),
                       y=free["country"].head(10),
                        orientation='h'
                       ), 1,1
                )
fig.append_trace(go.Bar(x=free['freedom'].tail(10),
                       y=free['country'].tail(10),
                        orientation='h'
                       ), 1,2
                )
fig.update_layout(
    template='ggplot2',
    showlegend=False)
fig.show()
# Out:
# <div>                            <div id="1c9a990b-786f-4152-9fd8-6d23386c3d73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c9a990b-786f-4152-9fd8-6d23386c3d73")) {                    Plotly.newPlot(                        "1c9a990b-786f-4152-9fd8-6d23386c3d73",                        [{"orientation": "h", "type": "bar", "x": [0.9544, 0.9450666666666668, 0.9396923076923078, 0.9315, 0.9296000000000001, 0.9279333333333335, 0.9247, 0.9231428571428573, 0.9217142857142857, 0.9196666666666667], "xaxis": "x", "y": ["Norway", "Denmark", "Finland", "Iceland", "Sweden", "Canada", "Switzerland", "New Zealand", "Australia", "Somalia"], "yaxis": "y"}, {"orientation": "h", "type": "bar", "x": [0.4995000000000001, 0.49761538461538457, 0.49374999999999997, 0.4779166666666666, 0.4690909090909091, 0.4616363636363637, 0.45625, 0.4508, 0.3893749999999999, 0.281], "xaxis": "x2", "y": ["Chad", "Bosnia and Herzegovina", "South Sudan", "Iraq", "Madagascar", "Haiti", "Angola", "Burundi", "Algeria", "Cuba"], "yaxis": "y2"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Top 10 Countries as freedom", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "The Lowest 10 Countries as freedom", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": " ...

# %%
corruption = data.groupby(["country"],as_index=False).mean().sort_values(by="corruption", ascending=False)
x = corruption[corruption['corruption'] > 0].tail(10)

fig = make_subplots(rows=1, cols=2,
                   subplot_titles=['Top 10 Countries as corruption', 'The Lowest 10 Countries as corruption'])
fig.append_trace(go.Bar(x=corruption['corruption'].head(10),
                       y=corruption["country"].head(10),
                        orientation='h'
                       ), 1,1
                )
fig.append_trace(go.Bar(x=x['corruption'].tail(10),
                       y=corruption['country'].tail(10),
                        orientation='h'
                       ), 1,2
                )
fig.update_layout(
    template='seaborn',
    showlegend=False)
fig.show()
# Out:
# <div>                            <div id="e2336a30-5cbe-4ba8-be7e-3a7a50daa7a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2336a30-5cbe-4ba8-be7e-3a7a50daa7a5")) {                    Plotly.newPlot(                        "e2336a30-5cbe-4ba8-be7e-3a7a50daa7a5",                        [{"orientation": "h", "type": "bar", "x": [0.9532307692307692, 0.9441538461538462, 0.9419999999999998, 0.9337333333333333, 0.9326, 0.9314285714285715, 0.927923076923077, 0.9269999999999999, 0.9211538461538462, 0.9183333333333333], "xaxis": "x", "y": ["Romania", "Bosnia and Herzegovina", "Bulgaria", "Moldova", "Ukraine", "Indonesia", "Croatia", "Trinidad and Tobago", "Portugal", "Lithuania"], "yaxis": "y"}, {"orientation": "h", "type": "bar", "x": [0.249, 0.2452, 0.20046666666666663, 0.1862727272727273, 0.18600000000000003, 0.18546666666666667, 0.0972, 0.09030769230769232, 0.069, 0.0368], "xaxis": "x2", "y": ["Jordan", "Saudi Arabia", "Singapore", "United Arab Emirates", "Qatar", "Maldives", "Cuba", "Oman", "Turkmenistan", "China"], "yaxis": "y2"}],                        {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Top 10 Countries as corruption", "x": 0.225, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "The Lowest 10 Countries as corruption", "x": 0.775, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(234,234,242)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67)"], [0.6274509803921569, "rgb(236,76,61)"], [0.6901960784313725, "rgb(242,107,73)"], [0.7529411764705882, "rgb(244,135,95)"], [0.8156862745098039, "rgb(245,162,122)"], [0.8784313725490196, "rgb(246,188,153)"], [0.9411764705882353, "rgb(247,212,187)"], [1.0, "rgb(250,234,220)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(36,36,36)", "ticklen": 8, "ticks": "outside", "tickwidth": 2}, "colorscale": [[0.0, "rgb(2,4,25)"], [0.06274509803921569, "rgb(24,15,41)"], [0.12549019607843137, "rgb(47,23,57)"], [0.18823529411764706, "rgb(71,28,72)"], [0.25098039215686274, "rgb(97,30,82)"], [0.3137254901960784, "rgb(123,30,89)"], [0.3764705882352941, "rgb(150,27,91)"], [0.4392156862745098, "rgb(177,22,88)"], [0.5019607843137255, "rgb(203,26,79)"], [0.5647058823529412, "rgb(223,47,67 ...

# %% [markdown]
# ### Regional Analysis

# %% [markdown]
# #### GDP per capita and Life expectancy

# %%
fig = px.scatter(data, y="life_expectancy", x="gdp_per_capita", size="ladder_score", color="region",
           hover_name="country", animation_frame="year", animation_group="country", log_x=True, size_max=12, template="ggplot2", title="GDP per capita by regions")
fig.show()
# Out:
# <div>                            <div id="57dd6e3c-418d-4baa-aa28-849e82dce578" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57dd6e3c-418d-4baa-aa28-849e82dce578")) {                    Plotly.newPlot(                        "57dd6e3c-418d-4baa-aa28-849e82dce578",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>region=South Asia<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Afghanistan", "Bangladesh", "India", "Nepal", "Pakistan", "Sri Lanka"], "ids": ["Afghanistan", "Bangladesh", "India", "Nepal", "Pakistan", "Sri Lanka"], "legendgroup": "South Asia", "marker": {"color": "#F8766D", "size": [3.724, 5.052, 5.146, 4.441, 4.414, 4.431], "sizemode": "area", "sizeref": 0.0556875, "symbol": "circle"}, "mode": "markers", "name": "South Asia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.37, 7.886, 8.22, 7.686, 8.271, 9.021], "xaxis": "x", "y": [50.8, 59.86, 56.56, 58.2, 55.4, 65.94], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>region=Central and Eastern Europe<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Estonia", "Kosovo", "Latvia", "Lithuania"], "ids": ["Estonia", "Kosovo", "Latvia", "Lithuania"], "legendgroup": "Central and Eastern Europe", "marker": {"color": "#A3A500", "size": [5.452, 5.522, 5.145, 5.554], "sizemode": "area", "sizeref": 0.0556875, "symbol": "circle"}, "mode": "markers", "name": "Central and Eastern Europe", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.298, 8.981, 10.112, 10.199], "xaxis": "x", "y": [65.78, 0.0, 63.88, 63.82], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>region=Middle East and North Africa<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Djibouti", "Egypt", "Iran", "Iraq", "Israel", "Jordan", "Lebanon", "Palestinian Territories", "Saudi Arabia", "Syria", "Turkey"], "ids": ["Djibouti", "Egypt", "Iran", "Iraq", "Israel", "Jordan", "Lebanon", "Palestinian Territories", "Saudi Arabia", "Syria", "Turkey"], "legendgroup": "Middle East and North Africa", "marker": {"color": "#00BF7D", "size": [5.009, 4.632, 5.129, 4.59, 7.261, 4.93, 4.595, 4.386, 6.811, 5.323, 5.118], "sizemode": "area", "sizeref": 0.0556875, "symbol": "circle"}, "mode": "markers", "name": "Middle East and North Africa", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.111, 9.186, 9.489, 9.063, 10.44, 9.343, 9.743, 8.276, 10.722, 8.652, 9.899], "xaxis": "x", "y": [53.26, 59.88, 63.14, 58.32, 71.76, 64.22, 64.96, 62.015, 64.04, 63.9, 63.68], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>region=Sub-Saharan Africa<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Chad", "Congo (Brazzaville)", "Ghana", "Kenya", "Liberia", "Madagascar", "Mali", "Mauritania", "Mozambique", "Niger", "Nigeria", "Rwanda", "Senegal", "Sierra Leone", "South Africa", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"], "ids": ["Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Chad", "Congo (Brazzaville)", "Ghana", "Kenya", "Liberia", "Madagascar", "Mali", "Mauritania", "Mozambique", "Niger", "Nigeria", "Rwanda", "Senegal", "Sierra Leone", "South Africa", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"], "legendgroup": "Sub-Saharan Africa", "marker": {"color": "#00B0F6", "size": [3.667, 5.451, 3.846, 3.563, 4.292, 4.632, 3.82, 4.965, 4.015, 4.221, 4.64, 4.115, 4.248, 4.654, 4.236, 4.939, 4.363, 4.683, 2.997, 5.346, 4.385, 2.808,  ...

# %%
for region in data.region.unique():
    fig = px.scatter(data[data["region"]==region], y="life_expectancy", x="gdp_per_capita", size="ladder_score", color="country",
           hover_name="country", animation_frame="year", animation_group="country", log_x=True, size_max=15, template="plotly_dark", title=region)
    fig.show()
# Out:
# <div>                            <div id="a6b15122-af9b-47ee-8e90-637ac875e0fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6b15122-af9b-47ee-8e90-637ac875e0fc")) {                    Plotly.newPlot(                        "a6b15122-af9b-47ee-8e90-637ac875e0fc",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Afghanistan<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Afghanistan"], "ids": ["Afghanistan"], "legendgroup": "Afghanistan", "marker": {"color": "#636efa", "size": [3.724], "sizemode": "area", "sizeref": 0.025915555555555556, "symbol": "circle"}, "mode": "markers", "name": "Afghanistan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.37], "xaxis": "x", "y": [50.8], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bangladesh<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Bangladesh"], "ids": ["Bangladesh"], "legendgroup": "Bangladesh", "marker": {"color": "#EF553B", "size": [5.052], "sizemode": "area", "sizeref": 0.025915555555555556, "symbol": "circle"}, "mode": "markers", "name": "Bangladesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.886], "xaxis": "x", "y": [59.86], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=India<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["India"], "ids": ["India"], "legendgroup": "India", "marker": {"color": "#ab63fa", "size": [5.146], "sizemode": "area", "sizeref": 0.025915555555555556, "symbol": "circle"}, "mode": "markers", "name": "India", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.22], "xaxis": "x", "y": [56.56], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Nepal<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Nepal"], "ids": ["Nepal"], "legendgroup": "Nepal", "marker": {"color": "#19d3f3", "size": [4.441], "sizemode": "area", "sizeref": 0.025915555555555556, "symbol": "circle"}, "mode": "markers", "name": "Nepal", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.686], "xaxis": "x", "y": [58.2], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Pakistan<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Pakistan"], "ids": ["Pakistan"], "legendgroup": "Pakistan", "marker": {"color": "#FF6692", "size": [4.414], "sizemode": "area", "sizeref": 0.025915555555555556, "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.271], "xaxis": "x", "y": [55.4], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Sri Lanka<br>year=2008<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Sri Lanka"], "ids": ["Sri Lanka"], "legendgroup": "Sri Lanka", "marker": {"color": "#B6E880", "size": [4.431], "sizemode": "area", "sizeref": 0.025915555555555556, "symbol": "circle"}, "mode": "markers", "name": "Sri Lanka", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.021], "xaxis": "x", "y": [65.94], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "country"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2008"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "tran ...
# <div>                            <div id="27a29676-1b7a-42e2-a31e-dcfd5a737923" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27a29676-1b7a-42e2-a31e-dcfd5a737923")) {                    Plotly.newPlot(                        "27a29676-1b7a-42e2-a31e-dcfd5a737923",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Albania<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Albania"], "ids": ["Albania"], "legendgroup": "Albania", "marker": {"color": "#636efa", "size": [4.634], "sizemode": "area", "sizeref": 0.03126222222222222, "symbol": "circle"}, "mode": "markers", "name": "Albania", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.142], "xaxis": "x", "y": [65.8], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bosnia and Herzegovina<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Bosnia and Herzegovina"], "ids": ["Bosnia and Herzegovina"], "legendgroup": "Bosnia and Herzegovina", "marker": {"color": "#EF553B", "size": [4.9], "sizemode": "area", "sizeref": 0.03126222222222222, "symbol": "circle"}, "mode": "markers", "name": "Bosnia and Herzegovina", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.267], "xaxis": "x", "y": [66.04], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bulgaria<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Bulgaria"], "ids": ["Bulgaria"], "legendgroup": "Bulgaria", "marker": {"color": "#00cc96", "size": [3.844], "sizemode": "area", "sizeref": 0.03126222222222222, "symbol": "circle"}, "mode": "markers", "name": "Bulgaria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.715], "xaxis": "x", "y": [65.1], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Croatia<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Croatia"], "ids": ["Croatia"], "legendgroup": "Croatia", "marker": {"color": "#ab63fa", "size": [5.821], "sizemode": "area", "sizeref": 0.03126222222222222, "symbol": "circle"}, "mode": "markers", "name": "Croatia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.162], "xaxis": "x", "y": [67.12], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Czech Republic<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Czech Republic"], "ids": ["Czech Republic"], "legendgroup": "Czech Republic", "marker": {"color": "#FFA15A", "size": [6.5], "sizemode": "area", "sizeref": 0.03126222222222222, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.437], "xaxis": "x", "y": [67.44], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Estonia<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Estonia"], "ids": ["Estonia"], "legendgroup": "Estonia", "marker": {"color": "#19d3f3", "size": [5.332], "sizemode": "area", "sizeref": 0.03126222222222222, "symbol": "circle"}, "mode": "markers", "name": "Estonia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.347], "xaxis": "x", "y": [65.32], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Hungary<br>year=2007<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Hungary"], "ids": ["Hungary"], "legendgroup": "Hungary", "marker": {"c ...
# <div>                            <div id="c621e39a-29da-483c-8894-68ec655017df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c621e39a-29da-483c-8894-68ec655017df")) {                    Plotly.newPlot(                        "c621e39a-29da-483c-8894-68ec655017df",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Algeria<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Algeria"], "ids": ["Algeria"], "legendgroup": "Algeria", "marker": {"color": "#636efa", "size": [5.464], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Algeria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.287], "xaxis": "x", "y": [64.5], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bahrain<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Bahrain"], "ids": ["Bahrain"], "legendgroup": "Bahrain", "marker": {"color": "#EF553B", "size": [5.937], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Bahrain", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.706], "xaxis": "x", "y": [66.3], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Djibouti<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Djibouti"], "ids": ["Djibouti"], "legendgroup": "Djibouti", "marker": {"color": "#00cc96", "size": [5.006], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Djibouti", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.812], "xaxis": "x", "y": [54.3], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Egypt<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Egypt"], "ids": ["Egypt"], "legendgroup": "Egypt", "marker": {"color": "#ab63fa", "size": [4.669], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Egypt", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.244], "xaxis": "x", "y": [60.0], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Iraq<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Iraq"], "ids": ["Iraq"], "legendgroup": "Iraq", "marker": {"color": "#19d3f3", "size": [5.065], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Iraq", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.112], "xaxis": "x", "y": [59.6], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Israel<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Israel"], "ids": ["Israel"], "legendgroup": "Israel", "marker": {"color": "#FF6692", "size": [7.359], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Israel", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.461], "xaxis": "x", "y": [72.4], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Jordan<br>year=2010<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Jordan"], "ids": ["Jordan"], "legendgroup": "Jordan", "marker": {"color": "#B6E880", "size": [5.57], "sizemode": "area", "sizeref": 0.033035555555555554, "symbol": "circle"}, "mode": "markers", "name": "Jor ...
# <div>                            <div id="9eebac64-c894-4813-93f9-322dde46e680" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9eebac64-c894-4813-93f9-322dde46e680")) {                    Plotly.newPlot(                        "9eebac64-c894-4813-93f9-322dde46e680",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Angola<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Angola"], "ids": ["Angola"], "legendgroup": "Angola", "marker": {"color": "#636efa", "size": [5.589], "sizemode": "area", "sizeref": 0.027737777777777778, "symbol": "circle"}, "mode": "markers", "name": "Angola", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.946], "xaxis": "x", "y": [52.5], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Benin<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Benin"], "ids": ["Benin"], "legendgroup": "Benin", "marker": {"color": "#EF553B", "size": [3.87], "sizemode": "area", "sizeref": 0.027737777777777778, "symbol": "circle"}, "mode": "markers", "name": "Benin", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.904], "xaxis": "x", "y": [51.98], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Botswana<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Botswana"], "ids": ["Botswana"], "legendgroup": "Botswana", "marker": {"color": "#00cc96", "size": [3.52], "sizemode": "area", "sizeref": 0.027737777777777778, "symbol": "circle"}, "mode": "markers", "name": "Botswana", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.6], "xaxis": "x", "y": [53.68], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Burkina Faso<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Burkina Faso"], "ids": ["Burkina Faso"], "legendgroup": "Burkina Faso", "marker": {"color": "#ab63fa", "size": [4.785], "sizemode": "area", "sizeref": 0.027737777777777778, "symbol": "circle"}, "mode": "markers", "name": "Burkina Faso", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.487], "xaxis": "x", "y": [50.24], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Burundi<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Burundi"], "ids": ["Burundi"], "legendgroup": "Burundi", "marker": {"color": "#FFA15A", "size": [3.706], "sizemode": "area", "sizeref": 0.027737777777777778, "symbol": "circle"}, "mode": "markers", "name": "Burundi", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6.748], "xaxis": "x", "y": [50.68], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cameroon<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Cameroon"], "ids": ["Cameroon"], "legendgroup": "Cameroon", "marker": {"color": "#19d3f3", "size": [4.434], "sizemode": "area", "sizeref": 0.027737777777777778, "symbol": "circle"}, "mode": "markers", "name": "Cameroon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.048], "xaxis": "x", "y": [48.7], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Central African Republic<br>year=2011<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Central African Republic"], "ids": ["Central African Republic"], "legendgroup": "Central African Republic", "marker": {"color": "#FF6692", "size" ...
# <div>                            <div id="2571bb92-1132-402e-b92a-947c1f30b2e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2571bb92-1132-402e-b92a-947c1f30b2e8")) {                    Plotly.newPlot(                        "2571bb92-1132-402e-b92a-947c1f30b2e8",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Argentina<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Argentina"], "ids": ["Argentina"], "legendgroup": "Argentina", "marker": {"color": "#636efa", "size": [6.313], "sizemode": "area", "sizeref": 0.03384444444444445, "symbol": "circle"}, "mode": "markers", "name": "Argentina", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.942], "xaxis": "x", "y": [66.82], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bolivia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Bolivia"], "ids": ["Bolivia"], "legendgroup": "Bolivia", "marker": {"color": "#00cc96", "size": [5.374], "sizemode": "area", "sizeref": 0.03384444444444445, "symbol": "circle"}, "mode": "markers", "name": "Bolivia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.686], "xaxis": "x", "y": [59.0], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Chile<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Chile"], "ids": ["Chile"], "legendgroup": "Chile", "marker": {"color": "#FFA15A", "size": [6.063], "sizemode": "area", "sizeref": 0.03384444444444445, "symbol": "circle"}, "mode": "markers", "name": "Chile", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.85], "xaxis": "x", "y": [68.66], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Colombia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Colombia"], "ids": ["Colombia"], "legendgroup": "Colombia", "marker": {"color": "#19d3f3", "size": [6.025], "sizemode": "area", "sizeref": 0.03384444444444445, "symbol": "circle"}, "mode": "markers", "name": "Colombia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.277], "xaxis": "x", "y": [65.22], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Costa Rica<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Costa Rica"], "ids": ["Costa Rica"], "legendgroup": "Costa Rica", "marker": {"color": "#FF6692", "size": [7.082], "sizemode": "area", "sizeref": 0.03384444444444445, "symbol": "circle"}, "mode": "markers", "name": "Costa Rica", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.565], "xaxis": "x", "y": [69.94], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cuba<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Cuba"], "ids": ["Cuba"], "legendgroup": "Cuba", "marker": {"color": "#B6E880", "size": [5.418], "sizemode": "area", "sizeref": 0.03384444444444445, "symbol": "circle"}, "mode": "markers", "name": "Cuba", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.0], "xaxis": "x", "y": [68.44], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Dominican Republic<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Dominican Republic"], "ids": ["Dominican Republic"], "legendgroup": "Dominican Republic", "marker": {"color": "#FF97FF", "size": [5.088], "sizemode": "area", "sizeref": 0 ...
# <div>                            <div id="52437376-94a8-4652-8466-c2e06dee14dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52437376-94a8-4652-8466-c2e06dee14dc")) {                    Plotly.newPlot(                        "52437376-94a8-4652-8466-c2e06dee14dc",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Armenia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Armenia"], "ids": ["Armenia"], "legendgroup": "Armenia", "marker": {"color": "#636efa", "size": [4.289], "sizemode": "area", "sizeref": 0.02919111111111111, "symbol": "circle"}, "mode": "markers", "name": "Armenia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.044], "xaxis": "x", "y": [64.8], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Azerbaijan<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Azerbaijan"], "ids": ["Azerbaijan"], "legendgroup": "Azerbaijan", "marker": {"color": "#EF553B", "size": [4.728], "sizemode": "area", "sizeref": 0.02919111111111111, "symbol": "circle"}, "mode": "markers", "name": "Azerbaijan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.17], "xaxis": "x", "y": [61.88], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Belarus<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Belarus"], "ids": ["Belarus"], "legendgroup": "Belarus", "marker": {"color": "#00cc96", "size": [5.658], "sizemode": "area", "sizeref": 0.02919111111111111, "symbol": "circle"}, "mode": "markers", "name": "Belarus", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.489], "xaxis": "x", "y": [61.1], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Georgia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Georgia"], "ids": ["Georgia"], "legendgroup": "Georgia", "marker": {"color": "#ab63fa", "size": [3.675], "sizemode": "area", "sizeref": 0.02919111111111111, "symbol": "circle"}, "mode": "markers", "name": "Georgia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.993], "xaxis": "x", "y": [65.12], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Kazakhstan<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Kazakhstan"], "ids": ["Kazakhstan"], "legendgroup": "Kazakhstan", "marker": {"color": "#FFA15A", "size": [5.476], "sizemode": "area", "sizeref": 0.02919111111111111, "symbol": "circle"}, "mode": "markers", "name": "Kazakhstan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.804], "xaxis": "x", "y": [58.2], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Kyrgyzstan<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Kyrgyzstan"], "ids": ["Kyrgyzstan"], "legendgroup": "Kyrgyzstan", "marker": {"color": "#19d3f3", "size": [4.641], "sizemode": "area", "sizeref": 0.02919111111111111, "symbol": "circle"}, "mode": "markers", "name": "Kyrgyzstan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.185], "xaxis": "x", "y": [59.98], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Moldova<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Moldova"], "ids": ["Moldova"], "legendgroup": "Moldova", "marker": {"color": "#FF6692", "size": [5.102], "sizemode": "area", "sizeref": 0.029 ...
# <div>                            <div id="c90d93fb-bc9b-4e82-84df-531818a93c4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c90d93fb-bc9b-4e82-84df-531818a93c4c")) {                    Plotly.newPlot(                        "c90d93fb-bc9b-4e82-84df-531818a93c4c",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Australia<br>year=2005<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Australia"], "ids": ["Australia"], "legendgroup": "Australia", "marker": {"color": "#636efa", "size": [7.341], "sizemode": "area", "sizeref": 0.034, "symbol": "circle"}, "mode": "markers", "name": "Australia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.659], "xaxis": "x", "y": [71.4], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Canada<br>year=2005<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Canada"], "ids": ["Canada"], "legendgroup": "Canada", "marker": {"color": "#EF553B", "size": [7.418], "sizemode": "area", "sizeref": 0.034, "symbol": "circle"}, "mode": "markers", "name": "Canada", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.652], "xaxis": "x", "y": [71.3], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "country"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2005"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2005", "method": "animate"}, {"args": [["2007"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2007", "method": "animate"}, {"args": [["2008"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2008", "method": "animate"}, {"args": [["2010"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2010", "method": "animate"}, {"args": [["2011"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2011", "method": "animate"}, {"args": [["2012"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2012", "method": "animate"}, {"args": [["2013"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2013", "method": "animate"}, {"args": [["2014"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2014", "method": "animate"}, {"args": [["2015"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2015", "method": "animate"}, {"args": [["2016"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2016", "method": "animate"}, {"args": [["2017"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2017", "method": "animate"}, {"args": [["2018"], {"frame": {"duration": 0, "redraw": ...
# <div>                            <div id="f9f4c21a-1cfc-4231-9e89-b8848ab9a7e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9f4c21a-1cfc-4231-9e89-b8848ab9a7e9")) {                    Plotly.newPlot(                        "f9f4c21a-1cfc-4231-9e89-b8848ab9a7e9",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Austria<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Austria"], "ids": ["Austria"], "legendgroup": "Austria", "marker": {"color": "#636efa", "size": [7.122], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "Austria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.842], "xaxis": "x", "y": [70.76], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cyprus<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Cyprus"], "ids": ["Cyprus"], "legendgroup": "Cyprus", "marker": {"color": "#00cc96", "size": [6.238], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "Cyprus", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.566], "xaxis": "x", "y": [71.44], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Finland<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#FFA15A", "size": [7.672], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.745], "xaxis": "x", "y": [69.76], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=France<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["France"], "ids": ["France"], "legendgroup": "France", "marker": {"color": "#19d3f3", "size": [6.583], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "France", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.659], "xaxis": "x", "y": [71.48], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Ireland<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Ireland"], "ids": ["Ireland"], "legendgroup": "Ireland", "marker": {"color": "#FECB52", "size": [7.144], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "Ireland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.972], "xaxis": "x", "y": [70.14], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Norway<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Norway"], "ids": ["Norway"], "legendgroup": "Norway", "marker": {"color": "#19d3f3", "size": [7.416], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "Norway", "orientation": "v", "showlegend": true, "type": "scatter", "x": [11.031], "xaxis": "x", "y": [71.32], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Portugal<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Portugal"], "ids": ["Portugal"], "legendgroup": "Portugal", "marker": {"color": "#FF6692", "size": [5.405], "sizemode": "area", "sizeref": 0.03564, "symbol": "circle"}, "mode": "markers", "name": "Portugal", "orientation": "v", "showlegend": true, "type": "scatt ...
# <div>                            <div id="7466aeca-47d7-4741-ad54-87208b40446a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7466aeca-47d7-4741-ad54-87208b40446a")) {                    Plotly.newPlot(                        "7466aeca-47d7-4741-ad54-87208b40446a",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cambodia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Cambodia"], "ids": ["Cambodia"], "legendgroup": "Cambodia", "marker": {"color": "#636efa", "size": [3.569], "sizemode": "area", "sizeref": 0.03138666666666667, "symbol": "circle"}, "mode": "markers", "name": "Cambodia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.746], "xaxis": "x", "y": [55.3], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Indonesia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Indonesia"], "ids": ["Indonesia"], "legendgroup": "Indonesia", "marker": {"color": "#EF553B", "size": [4.947], "sizemode": "area", "sizeref": 0.03138666666666667, "symbol": "circle"}, "mode": "markers", "name": "Indonesia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.85], "xaxis": "x", "y": [59.84], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Laos<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Laos"], "ids": ["Laos"], "legendgroup": "Laos", "marker": {"color": "#00cc96", "size": [5.076], "sizemode": "area", "sizeref": 0.03138666666666667, "symbol": "circle"}, "mode": "markers", "name": "Laos", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.251], "xaxis": "x", "y": [53.92], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Malaysia<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Malaysia"], "ids": ["Malaysia"], "legendgroup": "Malaysia", "marker": {"color": "#ab63fa", "size": [6.012], "sizemode": "area", "sizeref": 0.03138666666666667, "symbol": "circle"}, "mode": "markers", "name": "Malaysia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.839], "xaxis": "x", "y": [64.96], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Philippines<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Philippines"], "ids": ["Philippines"], "legendgroup": "Philippines", "marker": {"color": "#19d3f3", "size": [4.67], "sizemode": "area", "sizeref": 0.03138666666666667, "symbol": "circle"}, "mode": "markers", "name": "Philippines", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.562], "xaxis": "x", "y": [59.8], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Singapore<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Singapore"], "ids": ["Singapore"], "legendgroup": "Singapore", "marker": {"color": "#FF6692", "size": [6.463], "sizemode": "area", "sizeref": 0.03138666666666667, "symbol": "circle"}, "mode": "markers", "name": "Singapore", "orientation": "v", "showlegend": true, "type": "scatter", "x": [11.168], "xaxis": "x", "y": [73.6], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Thailand<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Thailand"], "ids": ["Thailand"], "legendgroup": "Thailand", "marker": {"color": "#B6E880", "size": [5.885], "sizemode": "area", "sizeref": 0.031386666 ...
# <div>                            <div id="4fba013d-71db-4072-a0a7-4aa65dfd263d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fba013d-71db-4072-a0a7-4aa65dfd263d")) {                    Plotly.newPlot(                        "4fba013d-71db-4072-a0a7-4aa65dfd263d",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=China<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["China"], "ids": ["China"], "legendgroup": "China", "marker": {"color": "#636efa", "size": [4.56], "sizemode": "area", "sizeref": 0.030875555555555555, "symbol": "circle"}, "mode": "markers", "name": "China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.696], "xaxis": "x", "y": [66.88], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Hong Kong S.A.R. of China<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Hong Kong S.A.R. of China"], "ids": ["Hong Kong S.A.R. of China"], "legendgroup": "Hong Kong S.A.R. of China", "marker": {"color": "#EF553B", "size": [5.511], "sizemode": "area", "sizeref": 0.030875555555555555, "symbol": "circle"}, "mode": "markers", "name": "Hong Kong S.A.R. of China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.746], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=South Korea<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["South Korea"], "ids": ["South Korea"], "legendgroup": "South Korea", "marker": {"color": "#FFA15A", "size": [5.332], "sizemode": "area", "sizeref": 0.030875555555555555, "symbol": "circle"}, "mode": "markers", "name": "South Korea", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.31], "xaxis": "x", "y": [70.2], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Taiwan Province of China<br>year=2006<br>gdp_per_capita=%{x}<br>life_expectancy=%{y}<br>ladder_score=%{marker.size}<extra></extra>", "hovertext": ["Taiwan Province of China"], "ids": ["Taiwan Province of China"], "legendgroup": "Taiwan Province of China", "marker": {"color": "#19d3f3", "size": [6.189], "sizemode": "area", "sizeref": 0.030875555555555555, "symbol": "circle"}, "mode": "markers", "name": "Taiwan Province of China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.613], "xaxis": "x", "y": [68.68], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "country"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2006"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2006", "method": "animate"}, {"args": [["2007"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2007", "method": "animate"}, {"args": [["2008"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2008", "method": "animate"}, {"args": [["2009"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2009", "method": "animate"}, {"args": [["2010"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2010", "method": "animate"}, ...

# %% [markdown]
# #### These plots shows that it is possible to say that the higher gdp_per_capita, the higher life expectancy.
#
# #### Bu animasyonlu grafikleri bölge bölge inceleyince gdp per capita arttıkça life expectancy için de artış olduğu görülmekte.

# %% [markdown]
# #### GDP per capita / Ladder Score

# %%
for region in data.region.unique():
    fig = px.scatter(data[data["region"]==region], y="ladder_score", x="gdp_per_capita", size="freedom", color="country",
           hover_name="country", animation_frame="year", animation_group="country", log_x=False, size_max=15, template="plotly_dark", title=region)
    fig.show()
# Out:
# <div>                            <div id="30cdbd21-a443-4a3e-a425-a17e58f9cff8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30cdbd21-a443-4a3e-a425-a17e58f9cff8")) {                    Plotly.newPlot(                        "30cdbd21-a443-4a3e-a425-a17e58f9cff8",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Afghanistan<br>year=2008<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Afghanistan"], "ids": ["Afghanistan"], "legendgroup": "Afghanistan", "marker": {"color": "#636efa", "size": [0.718], "sizemode": "area", "sizeref": 0.004026666666666667, "symbol": "circle"}, "mode": "markers", "name": "Afghanistan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.37], "xaxis": "x", "y": [3.724], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bangladesh<br>year=2008<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Bangladesh"], "ids": ["Bangladesh"], "legendgroup": "Bangladesh", "marker": {"color": "#EF553B", "size": [0.606], "sizemode": "area", "sizeref": 0.004026666666666667, "symbol": "circle"}, "mode": "markers", "name": "Bangladesh", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.886], "xaxis": "x", "y": [5.052], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=India<br>year=2008<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["India"], "ids": ["India"], "legendgroup": "India", "marker": {"color": "#ab63fa", "size": [0.756], "sizemode": "area", "sizeref": 0.004026666666666667, "symbol": "circle"}, "mode": "markers", "name": "India", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.22], "xaxis": "x", "y": [5.146], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Nepal<br>year=2008<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Nepal"], "ids": ["Nepal"], "legendgroup": "Nepal", "marker": {"color": "#19d3f3", "size": [0.618], "sizemode": "area", "sizeref": 0.004026666666666667, "symbol": "circle"}, "mode": "markers", "name": "Nepal", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.686], "xaxis": "x", "y": [4.441], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Pakistan<br>year=2008<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Pakistan"], "ids": ["Pakistan"], "legendgroup": "Pakistan", "marker": {"color": "#FF6692", "size": [0.335], "sizemode": "area", "sizeref": 0.004026666666666667, "symbol": "circle"}, "mode": "markers", "name": "Pakistan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.271], "xaxis": "x", "y": [4.414], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Sri Lanka<br>year=2008<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Sri Lanka"], "ids": ["Sri Lanka"], "legendgroup": "Sri Lanka", "marker": {"color": "#B6E880", "size": [0.834], "sizemode": "area", "sizeref": 0.004026666666666667, "symbol": "circle"}, "mode": "markers", "name": "Sri Lanka", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.021], "xaxis": "x", "y": [4.431], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "country"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2008"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}} ...
# <div>                            <div id="40f17dae-e5d5-467d-87e1-498aa41d6cbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40f17dae-e5d5-467d-87e1-498aa41d6cbc")) {                    Plotly.newPlot(                        "40f17dae-e5d5-467d-87e1-498aa41d6cbc",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Albania<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Albania"], "ids": ["Albania"], "legendgroup": "Albania", "marker": {"color": "#636efa", "size": [0.529], "sizemode": "area", "sizeref": 0.004257777777777778, "symbol": "circle"}, "mode": "markers", "name": "Albania", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.142], "xaxis": "x", "y": [4.634], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bosnia and Herzegovina<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Bosnia and Herzegovina"], "ids": ["Bosnia and Herzegovina"], "legendgroup": "Bosnia and Herzegovina", "marker": {"color": "#EF553B", "size": [0.342], "sizemode": "area", "sizeref": 0.004257777777777778, "symbol": "circle"}, "mode": "markers", "name": "Bosnia and Herzegovina", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.267], "xaxis": "x", "y": [4.9], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bulgaria<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Bulgaria"], "ids": ["Bulgaria"], "legendgroup": "Bulgaria", "marker": {"color": "#00cc96", "size": [0.566], "sizemode": "area", "sizeref": 0.004257777777777778, "symbol": "circle"}, "mode": "markers", "name": "Bulgaria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.715], "xaxis": "x", "y": [3.844], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Croatia<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Croatia"], "ids": ["Croatia"], "legendgroup": "Croatia", "marker": {"color": "#ab63fa", "size": [0.662], "sizemode": "area", "sizeref": 0.004257777777777778, "symbol": "circle"}, "mode": "markers", "name": "Croatia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.162], "xaxis": "x", "y": [5.821], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Czech Republic<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Czech Republic"], "ids": ["Czech Republic"], "legendgroup": "Czech Republic", "marker": {"color": "#FFA15A", "size": [0.799], "sizemode": "area", "sizeref": 0.004257777777777778, "symbol": "circle"}, "mode": "markers", "name": "Czech Republic", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.437], "xaxis": "x", "y": [6.5], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Estonia<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Estonia"], "ids": ["Estonia"], "legendgroup": "Estonia", "marker": {"color": "#19d3f3", "size": [0.712], "sizemode": "area", "sizeref": 0.004257777777777778, "symbol": "circle"}, "mode": "markers", "name": "Estonia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.347], "xaxis": "x", "y": [5.332], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Hungary<br>year=2007<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Hungary"], "ids": ["Hungary"], "legendgroup": "Hungary", "marker": {"color": "#FF6692", "size": [0.538], "sizemode": " ...
# <div>                            <div id="29f0e7c8-3fef-4f37-b7ee-eeca868ede64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29f0e7c8-3fef-4f37-b7ee-eeca868ede64")) {                    Plotly.newPlot(                        "29f0e7c8-3fef-4f37-b7ee-eeca868ede64",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Algeria<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Algeria"], "ids": ["Algeria"], "legendgroup": "Algeria", "marker": {"color": "#636efa", "size": [0.593], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Algeria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.287], "xaxis": "x", "y": [5.464], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bahrain<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Bahrain"], "ids": ["Bahrain"], "legendgroup": "Bahrain", "marker": {"color": "#EF553B", "size": [0.862], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Bahrain", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.706], "xaxis": "x", "y": [5.937], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Djibouti<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Djibouti"], "ids": ["Djibouti"], "legendgroup": "Djibouti", "marker": {"color": "#00cc96", "size": [0.764], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Djibouti", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.812], "xaxis": "x", "y": [5.006], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Egypt<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Egypt"], "ids": ["Egypt"], "legendgroup": "Egypt", "marker": {"color": "#ab63fa", "size": [0.486], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Egypt", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.244], "xaxis": "x", "y": [4.669], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Iraq<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Iraq"], "ids": ["Iraq"], "legendgroup": "Iraq", "marker": {"color": "#19d3f3", "size": [0.419], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Iraq", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.112], "xaxis": "x", "y": [5.065], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Israel<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Israel"], "ids": ["Israel"], "legendgroup": "Israel", "marker": {"color": "#FF6692", "size": [0.561], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Israel", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.461], "xaxis": "x", "y": [7.359], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Jordan<br>year=2010<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Jordan"], "ids": ["Jordan"], "legendgroup": "Jordan", "marker": {"color": "#B6E880", "size": [0.788], "sizemode": "area", "sizeref": 0.004302222222222222, "symbol": "circle"}, "mode": "markers", "name": "Jordan", "orientation": "v", "showlegend": true, "ty ...
# <div>                            <div id="ce931114-266c-4153-9f08-c131761065a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce931114-266c-4153-9f08-c131761065a6")) {                    Plotly.newPlot(                        "ce931114-266c-4153-9f08-c131761065a6",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Angola<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Angola"], "ids": ["Angola"], "legendgroup": "Angola", "marker": {"color": "#636efa", "size": [0.584], "sizemode": "area", "sizeref": 0.0041066666666666665, "symbol": "circle"}, "mode": "markers", "name": "Angola", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.946], "xaxis": "x", "y": [5.589], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Benin<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Benin"], "ids": ["Benin"], "legendgroup": "Benin", "marker": {"color": "#EF553B", "size": [0.773], "sizemode": "area", "sizeref": 0.0041066666666666665, "symbol": "circle"}, "mode": "markers", "name": "Benin", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.904], "xaxis": "x", "y": [3.87], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Botswana<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Botswana"], "ids": ["Botswana"], "legendgroup": "Botswana", "marker": {"color": "#00cc96", "size": [0.813], "sizemode": "area", "sizeref": 0.0041066666666666665, "symbol": "circle"}, "mode": "markers", "name": "Botswana", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.6], "xaxis": "x", "y": [3.52], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Burkina Faso<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Burkina Faso"], "ids": ["Burkina Faso"], "legendgroup": "Burkina Faso", "marker": {"color": "#ab63fa", "size": [0.725], "sizemode": "area", "sizeref": 0.0041066666666666665, "symbol": "circle"}, "mode": "markers", "name": "Burkina Faso", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.487], "xaxis": "x", "y": [4.785], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Burundi<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Burundi"], "ids": ["Burundi"], "legendgroup": "Burundi", "marker": {"color": "#FFA15A", "size": [0.49], "sizemode": "area", "sizeref": 0.0041066666666666665, "symbol": "circle"}, "mode": "markers", "name": "Burundi", "orientation": "v", "showlegend": true, "type": "scatter", "x": [6.748], "xaxis": "x", "y": [3.706], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cameroon<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Cameroon"], "ids": ["Cameroon"], "legendgroup": "Cameroon", "marker": {"color": "#19d3f3", "size": [0.817], "sizemode": "area", "sizeref": 0.0041066666666666665, "symbol": "circle"}, "mode": "markers", "name": "Cameroon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.048], "xaxis": "x", "y": [4.434], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Central African Republic<br>year=2011<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Central African Republic"], "ids": ["Central African Republic"], "legendgroup": "Central African Republic", "marker": {"color": "#FF6692", "size": [0.78], "sizemode": "area", "sizeref": 0.004106 ...
# <div>                            <div id="0d705155-4e98-46f6-9c5f-28d1a809bb85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d705155-4e98-46f6-9c5f-28d1a809bb85")) {                    Plotly.newPlot(                        "0d705155-4e98-46f6-9c5f-28d1a809bb85",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Argentina<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Argentina"], "ids": ["Argentina"], "legendgroup": "Argentina", "marker": {"color": "#636efa", "size": [0.733], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode": "markers", "name": "Argentina", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.942], "xaxis": "x", "y": [6.313], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Bolivia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Bolivia"], "ids": ["Bolivia"], "legendgroup": "Bolivia", "marker": {"color": "#00cc96", "size": [0.77], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode": "markers", "name": "Bolivia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.686], "xaxis": "x", "y": [5.374], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Chile<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Chile"], "ids": ["Chile"], "legendgroup": "Chile", "marker": {"color": "#FFA15A", "size": [0.744], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode": "markers", "name": "Chile", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.85], "xaxis": "x", "y": [6.063], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Colombia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Colombia"], "ids": ["Colombia"], "legendgroup": "Colombia", "marker": {"color": "#19d3f3", "size": [0.805], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode": "markers", "name": "Colombia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.277], "xaxis": "x", "y": [6.025], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Costa Rica<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Costa Rica"], "ids": ["Costa Rica"], "legendgroup": "Costa Rica", "marker": {"color": "#FF6692", "size": [0.882], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode": "markers", "name": "Costa Rica", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.565], "xaxis": "x", "y": [7.082], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cuba<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Cuba"], "ids": ["Cuba"], "legendgroup": "Cuba", "marker": {"color": "#B6E880", "size": [0.281], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode": "markers", "name": "Cuba", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.0], "xaxis": "x", "y": [5.418], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Dominican Republic<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Dominican Republic"], "ids": ["Dominican Republic"], "legendgroup": "Dominican Republic", "marker": {"color": "#FF97FF", "size": [0.858], "sizemode": "area", "sizeref": 0.004186666666666667, "symbol": "circle"}, "mode":  ...
# <div>                            <div id="d5ebbbd3-e443-482b-b662-f9f47203545f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5ebbbd3-e443-482b-b662-f9f47203545f")) {                    Plotly.newPlot(                        "d5ebbbd3-e443-482b-b662-f9f47203545f",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Armenia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Armenia"], "ids": ["Armenia"], "legendgroup": "Armenia", "marker": {"color": "#636efa", "size": [0.52], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "markers", "name": "Armenia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.044], "xaxis": "x", "y": [4.289], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Azerbaijan<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Azerbaijan"], "ids": ["Azerbaijan"], "legendgroup": "Azerbaijan", "marker": {"color": "#EF553B", "size": [0.772], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "markers", "name": "Azerbaijan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.17], "xaxis": "x", "y": [4.728], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Belarus<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Belarus"], "ids": ["Belarus"], "legendgroup": "Belarus", "marker": {"color": "#00cc96", "size": [0.707], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "markers", "name": "Belarus", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.489], "xaxis": "x", "y": [5.658], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Georgia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Georgia"], "ids": ["Georgia"], "legendgroup": "Georgia", "marker": {"color": "#ab63fa", "size": [0.553], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "markers", "name": "Georgia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.993], "xaxis": "x", "y": [3.675], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Kazakhstan<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Kazakhstan"], "ids": ["Kazakhstan"], "legendgroup": "Kazakhstan", "marker": {"color": "#FFA15A", "size": [0.731], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "markers", "name": "Kazakhstan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.804], "xaxis": "x", "y": [5.476], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Kyrgyzstan<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Kyrgyzstan"], "ids": ["Kyrgyzstan"], "legendgroup": "Kyrgyzstan", "marker": {"color": "#19d3f3", "size": [0.678], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "markers", "name": "Kyrgyzstan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.185], "xaxis": "x", "y": [4.641], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Moldova<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Moldova"], "ids": ["Moldova"], "legendgroup": "Moldova", "marker": {"color": "#FF6692", "size": [0.554], "sizemode": "area", "sizeref": 0.004377777777777777, "symbol": "circle"}, "mode": "m ...
# <div>                            <div id="5e221d67-77e1-4b47-b496-75b8e4710942" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e221d67-77e1-4b47-b496-75b8e4710942")) {                    Plotly.newPlot(                        "5e221d67-77e1-4b47-b496-75b8e4710942",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Australia<br>year=2005<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Australia"], "ids": ["Australia"], "legendgroup": "Australia", "marker": {"color": "#636efa", "size": [0.935], "sizemode": "area", "sizeref": 0.004253333333333333, "symbol": "circle"}, "mode": "markers", "name": "Australia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.659], "xaxis": "x", "y": [7.341], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Canada<br>year=2005<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Canada"], "ids": ["Canada"], "legendgroup": "Canada", "marker": {"color": "#EF553B", "size": [0.957], "sizemode": "area", "sizeref": 0.004253333333333333, "symbol": "circle"}, "mode": "markers", "name": "Canada", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.652], "xaxis": "x", "y": [7.418], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "country"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2005"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2005", "method": "animate"}, {"args": [["2007"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2007", "method": "animate"}, {"args": [["2008"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2008", "method": "animate"}, {"args": [["2010"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2010", "method": "animate"}, {"args": [["2011"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2011", "method": "animate"}, {"args": [["2012"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2012", "method": "animate"}, {"args": [["2013"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2013", "method": "animate"}, {"args": [["2014"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2014", "method": "animate"}, {"args": [["2015"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2015", "method": "animate"}, {"args": [["2016"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2016", "method": "animate"}, {"args": [["2017"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2017", "method": "animate"}, {"args": [["2018"], {"frame": {"duratio ...
# <div>                            <div id="7d2960f4-58ec-4a6a-8f1a-61f004af2353" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d2960f4-58ec-4a6a-8f1a-61f004af2353")) {                    Plotly.newPlot(                        "7d2960f4-58ec-4a6a-8f1a-61f004af2353",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Austria<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Austria"], "ids": ["Austria"], "legendgroup": "Austria", "marker": {"color": "#636efa", "size": [0.941], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "Austria", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.842], "xaxis": "x", "y": [7.122], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cyprus<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Cyprus"], "ids": ["Cyprus"], "legendgroup": "Cyprus", "marker": {"color": "#00cc96", "size": [0.836], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "Cyprus", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.566], "xaxis": "x", "y": [6.238], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Finland<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#FFA15A", "size": [0.969], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.745], "xaxis": "x", "y": [7.672], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=France<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["France"], "ids": ["France"], "legendgroup": "France", "marker": {"color": "#19d3f3", "size": [0.789], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "France", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.659], "xaxis": "x", "y": [6.583], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Ireland<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Ireland"], "ids": ["Ireland"], "legendgroup": "Ireland", "marker": {"color": "#FECB52", "size": [0.943], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "Ireland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.972], "xaxis": "x", "y": [7.144], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Norway<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Norway"], "ids": ["Norway"], "legendgroup": "Norway", "marker": {"color": "#19d3f3", "size": [0.96], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "Norway", "orientation": "v", "showlegend": true, "type": "scatter", "x": [11.031], "xaxis": "x", "y": [7.416], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Portugal<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Portugal"], "ids": ["Portugal"], "legendgroup": "Portugal", "marker": {"color": "#FF6692", "size": [0.882], "sizemode": "area", "sizeref": 0.004315555555555555, "symbol": "circle"}, "mode": "markers", "name": "Portugal", "orientation": "v",  ...
# <div>                            <div id="38fefd8b-221c-46f7-89e3-563cbeb89aec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38fefd8b-221c-46f7-89e3-563cbeb89aec")) {                    Plotly.newPlot(                        "38fefd8b-221c-46f7-89e3-563cbeb89aec",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=Cambodia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Cambodia"], "ids": ["Cambodia"], "legendgroup": "Cambodia", "marker": {"color": "#636efa", "size": [0.0], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers", "name": "Cambodia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.746], "xaxis": "x", "y": [3.569], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Indonesia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Indonesia"], "ids": ["Indonesia"], "legendgroup": "Indonesia", "marker": {"color": "#EF553B", "size": [0.713], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers", "name": "Indonesia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.85], "xaxis": "x", "y": [4.947], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Laos<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Laos"], "ids": ["Laos"], "legendgroup": "Laos", "marker": {"color": "#00cc96", "size": [0.925], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers", "name": "Laos", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.251], "xaxis": "x", "y": [5.076], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Malaysia<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Malaysia"], "ids": ["Malaysia"], "legendgroup": "Malaysia", "marker": {"color": "#ab63fa", "size": [0.837], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers", "name": "Malaysia", "orientation": "v", "showlegend": true, "type": "scatter", "x": [9.839], "xaxis": "x", "y": [6.012], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Philippines<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Philippines"], "ids": ["Philippines"], "legendgroup": "Philippines", "marker": {"color": "#19d3f3", "size": [0.828], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers", "name": "Philippines", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.562], "xaxis": "x", "y": [4.67], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Singapore<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Singapore"], "ids": ["Singapore"], "legendgroup": "Singapore", "marker": {"color": "#FF6692", "size": [0.757], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers", "name": "Singapore", "orientation": "v", "showlegend": true, "type": "scatter", "x": [11.168], "xaxis": "x", "y": [6.463], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Thailand<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Thailand"], "ids": ["Thailand"], "legendgroup": "Thailand", "marker": {"color": "#B6E880", "size": [0.863], "sizemode": "area", "sizeref": 0.004284444444444444, "symbol": "circle"}, "mode": "markers" ...
# <div>                            <div id="e8cbbbf8-6fa6-433b-94d0-d4b0790a4934" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8cbbbf8-6fa6-433b-94d0-d4b0790a4934")) {                    Plotly.newPlot(                        "e8cbbbf8-6fa6-433b-94d0-d4b0790a4934",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>country=China<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["China"], "ids": ["China"], "legendgroup": "China", "marker": {"color": "#636efa", "size": [0.0], "sizemode": "area", "sizeref": 0.00412, "symbol": "circle"}, "mode": "markers", "name": "China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [8.696], "xaxis": "x", "y": [4.56], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Hong Kong S.A.R. of China<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Hong Kong S.A.R. of China"], "ids": ["Hong Kong S.A.R. of China"], "legendgroup": "Hong Kong S.A.R. of China", "marker": {"color": "#EF553B", "size": [0.91], "sizemode": "area", "sizeref": 0.00412, "symbol": "circle"}, "mode": "markers", "name": "Hong Kong S.A.R. of China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.746], "xaxis": "x", "y": [5.511], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=South Korea<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["South Korea"], "ids": ["South Korea"], "legendgroup": "South Korea", "marker": {"color": "#FFA15A", "size": [0.715], "sizemode": "area", "sizeref": 0.00412, "symbol": "circle"}, "mode": "markers", "name": "South Korea", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.31], "xaxis": "x", "y": [5.332], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>country=Taiwan Province of China<br>year=2006<br>gdp_per_capita=%{x}<br>ladder_score=%{y}<br>freedom=%{marker.size}<extra></extra>", "hovertext": ["Taiwan Province of China"], "ids": ["Taiwan Province of China"], "legendgroup": "Taiwan Province of China", "marker": {"color": "#19d3f3", "size": [0.63], "sizemode": "area", "sizeref": 0.00412, "symbol": "circle"}, "mode": "markers", "name": "Taiwan Province of China", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.613], "xaxis": "x", "y": [6.189], "yaxis": "y"}],                        {"legend": {"itemsizing": "constant", "title": {"text": "country"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2006"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2006", "method": "animate"}, {"args": [["2007"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2007", "method": "animate"}, {"args": [["2008"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2008", "method": "animate"}, {"args": [["2009"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2009", "method": "animate"}, {"args": [["2010"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2010", "method": "animate"}, {"args": [["2011"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, ...
